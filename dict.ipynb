# %%
studentinfo = {
 "name" : "Muhammad Adeel Munir",
 "reg" : "MC-BSCS-239-033",
 "dep" : "computer science",
 "session" : "fall 2023"
}

# print(studentinfo,type(studentinfo))
print(studentinfo["reg"])
# Out:
# MC-BSCS-239-033
