# %%
# now i am going to print hello word
print("hello world")

# now we use variables
a = 100
b = "adeel"

# we print int and string type vlues collectively like this
print(a , b)

'''
adeel is a
verry intelligent
boy

'''
c = 15
print(f"the sum of a+b is : {a+c} ")
# Out:
# hello world
# 100 adeel
# the sum of a+b is : 115
