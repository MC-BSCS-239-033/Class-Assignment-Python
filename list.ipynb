# %%
# now we are going to make a list
fruit = ["orange","banana","apple"]
print(fruit,type(fruit))

# Another list 
l = ["adeel",False,"python",233]
print(l,type(l))
# Out:
# ['orange', 'banana', 'apple'] <class 'list'>
# ['adeel', False, 'python', 233] <class 'list'>
