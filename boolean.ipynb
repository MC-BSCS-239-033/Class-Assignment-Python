# %%
# MULTILINE COMMENT
'''
   HERE IS OUR 
   CLASS ASSIGNMENT
   WHICH IS BOOLEAN
   TYPE OPERATION LET'S START 
'''
# now we takes input from user
# and perform boolean operators
a = int(input("Enter number 1:" ))
b = int(input("Enter number 2:" )) 

print(a)
print(b)

# boolean operators
print(a==b)
print(a>b)
print(a<b)

# by taking input in string and print  our name
name = input("Enter your name here:")
print(f"my name is: {name}")
# Out:
# 2
# 3
# False
# False
# True
# my name is: adeel
